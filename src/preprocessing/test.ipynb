# %%
import matplotlib.pyplot as plt
import pandas as pd
import os

# %%
df1 = pd.read_csv("./bus_tracker_results/online-clusters/1.csv", index_col=[0], parse_dates=[0], header=None)
df2 = pd.read_csv("./bus_tracker_results/online-clusters/6.csv", index_col=[0], parse_dates=[0], header=None)
df3 = pd.read_csv("./bus_tracker_results/online-clusters/7.csv", index_col=[0], parse_dates=[0], header=None)
df4 = pd.read_csv("./bus_tracker_results/online-clusters/43.csv", index_col=[0], parse_dates=[0], header=None)

# %%
df1.plot(figsize=(25,5))
df2.plot(figsize=(25,5))
df3.plot(figsize=(25,5))
df4.plot(figsize=(25,5))
# Out:
# <AxesSubplot:xlabel='0'>

# %% [markdown]
# # Admissions

# %%
dir_path = "./admission_results/online-clusters/"
files = os.listdir(dir_path)
for file in files:
  df = pd.read_csv(os.path.join(dir_path, file), index_col=[0], parse_dates=[0], header=None)
  df.plot(figsize=(25,2))
